# %%
import pickle

with open("/home/zixuanwe/zixuanwe/CoELA/test_results/LLMs_comm_gpt-5-mini/results.pik", "rb") as f:
    data = pickle.load(f)

print(type(data))
print(data)
# Out:
# <class 'dict'>
# {0: {'S': [1], 'L': [134]}, 5: {'S': [1], 'L': [63]}, 10: {'S': [1], 'L': [32]}, 16: {'S': [1], 'L': [64]}, 20: {'S': [1], 'L': [64]}, 26: {'S': [1], 'L': [95]}, 30: {'S': [1], 'L': [54]}, 32: {'S': [1], 'L': [82]}, 40: {'S': [1], 'L': [35]}, 49: {'S': [1], 'L': [36]}}

# %%
import pickle
data = pickle.load(open('cwah/dataset/test_env_set_help.pik', 'rb'))
print(len(data))
for i, x in enumerate(data[:5]):
    print(i, x.keys())
    print('task_id:', x['task_id'], 'env_id:', x['env_id'], 'task_name:', x['task_name'])
    print('task_goal:', x['task_goal'])
